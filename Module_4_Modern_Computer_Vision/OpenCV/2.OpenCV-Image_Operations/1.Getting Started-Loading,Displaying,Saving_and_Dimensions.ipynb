# %% [markdown]
# # **MODERN COMPUTER VISION** #
# ##### BY RAJEEV RATAN

# %% [markdown]
# <h2 style="margin-bottom:0;">🚀 Getting Started</h2>
#
# <h5 style="margin-top:5px;">Welcome to your first OpenCV Lesson. Here we'll learn to:</h5>
#
# <p style="margin-top:0;">
# 1️⃣ Import the OpenCV Model in Python <br>
# 2️⃣ Load Images <br>
# 3️⃣ Display Images <br>
# 4️⃣ Save Images <br>
# 5️⃣ Get the Image Dimensions
# </p>

# %%
# Install dependencies
# !pip install --upgrade pip
# !pip install opencv-python
# !pip install matplotlib
# Out:
# Requirement already satisfied: pip in c:\users\robin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (25.2)
# Requirement already satisfied: opencv-python in c:\users\robin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (4.12.0.88)
# Requirement already satisfied: numpy<2.3.0,>=2 in c:\users\robin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from opencv-python) (2.2.6)
# Requirement already satisfied: matplotlib in c:\users\robin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (3.10.7)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\robin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\robin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\robin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\robin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\robin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in c:\users\robin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\robin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\robin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\robin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\robin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
# This is how we import OpenCV, we can't use OpenCV's functions without first doing this
import cv2

# Let's see what version we're running
print(cv2.__version__)

# %% [markdown]
# ### **Loading Images** ###

# %%
# Load an image using 'imread' specifying the path to image
image = cv2.imread('images/flowers.jpg')

# %% [markdown]
# ### **Displaying Images** ###

# %%
from matplotlib import pyplot as plt

# Show the image with matplotlib
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

# %%
def imshow(title = "", image = None):
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.title(title)
    plt.show()

# Let's test it out
imshow("Displaying Our First Image", image)

# %% [markdown]
# ### **Saving Images** ###

# %%
# Simply use 'imwrite', specifying the file name and the image to be saved
cv2.imwrite('images/output.jpg', image)
# Out:
# True

# %%
# Or save it as a PNG (Portable Network Graphics) which is a Lossless bitmap image format
cv2.imwrite('images/output.png', image)
# Out:
# True

# %% [markdown]
# ### **Displaying Image Dimensions** ###

# %%
# Import numpy
import numpy as np

print(image.shape)
# Out:
# (600, 600, 3)

# %%
# To access a dimension, simply index it by using 0, 1 or 2
image.shape[0]
# Out:
# 600

# %%
print('Height of Image: {} pixels'.format(int(image.shape[0])))
print('Width of Image: {} pixels'.format(int(image.shape[1])))
print('Depth of Image: {} colors components'.format(int(image.shape[2])))
# Out:
# Height of Image: 600 pixels
# Width of Image: 600 pixels
# Depth of Image: 3 colors components
