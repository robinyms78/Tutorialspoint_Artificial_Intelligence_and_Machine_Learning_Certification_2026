# %% [markdown]
# # **MODERN COMPUTER VISION** #
# ##### BY RAJEEV RATAN

# %% [markdown]
# <h2 style="margin-bottom:0;">🚀 Grayscaling Images</h2>
#
# <h5 style="margin-top:5px;">In this lesson, we'll learn to:</h5>
#
# <p style="margin-top:0;">
# 1️⃣ Convert a colour image to grayscale <br>
# 2️⃣ See the change in dimensions between grayscale and colour images <br>
# </p>

# %% [markdown]
# ### **Loading Images** ###

# %%
import cv2
from matplotlib import pyplot as plt

# %%
# Define our imshow function
def imshow(title = "Image", image = None, size = 10):
    w, h = image.shape[0], image.shape[1]
    aspect_ratio = w/h
    plt.figure(figsize=(size * aspect_ratio, size))
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.title(title)
    plt.show()

# %%
# Load our input image
image = cv2.imread('images/flowers.jpg')
imshow("Flower", image)

# %%
# We use cvtColor, to convert to grayscale
# It takes 2 arguments, the first being the input image
# The second being the colour space conversion code
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

imshow("Converted to Grayscale", gray_image)

# %% [markdown]
# ### **Grayscale Image Dimensions** ###

# %%
image.shape
# Out:
# (600, 600, 3)

# %%
gray_image.shape
# Out:
# (600, 600)
